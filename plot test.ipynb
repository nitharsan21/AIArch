# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(figsize=(15, 3 * 6), nrows=2, ncols=3,)

# %%
ax = axes.flatten()[0]

# %%
ax
# Out:
# <Axes: >

# %%
plt.subplot(axes.flatten()[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 plt.subplot(axes.flatten()[0])
#
# File ~\Anaconda3\envs\AIArch\lib\site-packages\matplotlib\pyplot.py:1323, in subplot(*args, **kwargs)
#    1320 fig = gcf()
#    1322 # First, search for an existing subplot with a matching spec.
# -> 1323 key = SubplotSpec._from_subplot_args(fig, args)
#    1325 for ax in fig.axes:
#    1326     # if we found an Axes at the position sort out if we can re-use it
#    1327     if ax.get_subplotspec() == key:
#    1328         # if the user passed no kwargs, re-use
#
# File ~\Anaconda3\envs\AIArch\lib\site-packages\matplotlib\gridspec.py:573, in SubplotSpec._from_subplot_args(figure, args)
#     571     return arg
#     572 elif not isinstance(arg, Integral):
# --> 573     raise ValueError(
#     574         f"Single argument to subplot must be a three-digit "
# ...

# %%
print(axes.flatten()[0])
# Out:
# Axes(0.125,0.53;0.227941x0.35)

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(figsize=(15, 3 * 6), nrows=2, ncols=3)
axes = axes.flatten()  # Flatten the axes array

# Select the first subplot using the axes array
plt.subplot(axes[0])

# Rest of your code for plotting

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 7
#       4 axes = axes.flatten()  # Flatten the axes array
#       6 # Select the first subplot using the axes array
# ----> 7 plt.subplot(axes[0])
#       9 # Rest of your code for plotting
#      11 plt.show()
#
# File ~\Anaconda3\envs\AIArch\lib\site-packages\matplotlib\pyplot.py:1323, in subplot(*args, **kwargs)
#    1320 fig = gcf()
#    1322 # First, search for an existing subplot with a matching spec.
# -> 1323 key = SubplotSpec._from_subplot_args(fig, args)
#    1325 for ax in fig.axes:
#    1326     # if we found an Axes at the position sort out if we can re-use it
#    1327     if ax.get_subplotspec() == key:
#    1328         # if the user passed no kwargs, re-use
#
# File ~\Anaconda3\envs\AIArch\lib\site-packages\matplotlib\gridspec.py:573, in SubplotSpec._from_subplot_args(figure, args)
# ...

# %%
fig, axes = plt.subplots(figsize=(15, 3 * 6), nrows=2, ncols=3)

# Select the first subplot using indexing
axes[0, 0].plot(x, y)  # Replace `x` and `y` with your actual data

# Rest of your code for plotting

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 fig, axes = plt.subplots(figsize=(15, 3 * 6), nrows=2, ncols=3)
#       3 # Select the first subplot using indexing
# ----> 4 axes[0, 0].plot(x, y)  # Replace `x` and `y` with your actual data
#       6 # Rest of your code for plotting
#       8 plt.show()
#
# NameError: name 'x' is not defined

# %%
1 +1
